# %% [markdown]
# # Environment Check
#
# This notebook verifies that my Python data science environment is set up correctly.

# %%
import sys
sys.version
# Out:
# '3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %%
data = {
    "age": [35, 52, 29],
    "smoker": ["No", "Yes", "No"],
    "risk_band": ["Low", "High", "Low"]
}

df = pd.DataFrame(data)
df
# Out:
#    age smoker risk_band
# 0   35     No       Low
# 1   52    Yes      High
# 2   29     No       Low

# %% [markdown]
# This confirms that I can create and inspect tabular data using pandas,
# which will be the foundation for underwriting-style analysis.
